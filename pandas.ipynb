# %%
import numpy as np
import pandas as pd

# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":["rohan","seema","mahesh","shruti"],"marks":[9,55,67,98],"city":["delhi","jaipur","rampur","bari"]
}

# %%
df=pd.DataFrame(dict1)

# %%
df.index=[1,2,3,4]

# %%
df

# %%
ser=pd.Series(np.random.rand(20))

# %%
ser

# %%
type(ser)

# %%
newdf=pd.DataFrame(np.random.rand(334,5))

# %%
newdf

# %%
newdf.head(3)

# %%
newdf.tail(3)

# %%
newdf.sort_index(axis=0)

# %%
newdf.drop(0,axis=1)

# %%
newdf.dropna(inplace=True)
